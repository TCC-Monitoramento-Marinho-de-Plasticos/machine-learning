# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Result
#
#
# arise@sptech03373:~/Downloads/MiniGPTv01$ python3 BaseGPTv02.py
# 2025-11-04 15:44:08,611 - MiniGPT - INFO - 🚀 Iniciando MiniGPT v2.0...
# 2025-11-04 15:44:08,611 - MiniGPT - INFO - Configurações: batch_size=32, block_size=64
# 2025-11-04 15:44:08,611 - MiniGPT - INFO - 📚 Carregando e processando dados...
# 2025-11-04 15:44:08,611 - MiniGPT - INFO - Texto carregado: 8922 caracteres
# 2025-11-04 15:44:08,611 - MiniGPT - INFO - Vocabulário criado com 66 caracteres únicos
# 2025-11-04 15:44:08,611 - MiniGPT - INFO - Amostra do vocabulário:
#  ,-.5ABCDEFGHIJKLMNOPQRSTUWab...
# 2025-11-04 15:44:08,615 - MiniGPT - INFO - Dados divididos: 8029 treino, 893 validação
# 2025-11-04 15:44:08,615 - MiniGPT - INFO - 🧠 Criando modelo...
# 2025-11-04 15:44:08,729 - MiniGPT - INFO - 🎯 Iniciando treinamento...
# 2025-11-04 15:44:09,543 - MiniGPT - INFO - Iniciando treinamento...
# 2025-11-04 15:44:09,544 - MiniGPT - INFO - Parâmetros do modelo: 1.21M
# 2025-11-04 15:44:09,544 - MiniGPT - INFO - Dispositivo: cpu
# 2025-11-04 15:44:44,807 - MiniGPT - INFO - Iteração 0: perda treino 4.1679, perda validação 4.1638
# 2025-11-04 15:47:13,130 - MiniGPT - INFO - Iteração 300: perda treino 2.0872, perda validação 2.2200
# 2025-11-04 15:49:25,113 - MiniGPT - INFO - Iteração 600: perda treino 1.2523, perda validação 1.9951
# 2025-11-04 15:51:37,395 - MiniGPT - INFO - Iteração 900: perda treino 0.5549, perda validação 2.1797
# 2025-11-04 15:53:25,985 - MiniGPT - INFO - Iteração 1200: perda treino 0.2809, perda validação 2.4333
# 2025-11-04 15:55:10,611 - MiniGPT - INFO - Iteração 1500: perda treino 0.1995, perda validação 2.6322
# 2025-11-04 15:57:15,608 - MiniGPT - INFO - Iteração 1800: perda treino 0.1716, perda validação 2.8269
# 2025-11-04 15:59:15,487 - MiniGPT - INFO - Iteração 2100: perda treino 0.1588, perda validação 2.9706
# 2025-11-04 16:01:00,848 - MiniGPT - INFO - Iteração 2400: perda treino 0.1466, perda validação 3.0481
# 2025-11-04 16:03:09,945 - MiniGPT - INFO - Iteração 2700: perda treino 0.1406, perda validação 3.0230
# 2025-11-04 16:04:47,767 - MiniGPT - INFO - Iteração 2999: perda treino 0.1357, perda validação 3.0753
# 2025-11-04 16:04:48,033 - MiniGPT - INFO - Treinamento concluído!
# 2025-11-04 16:04:48,034 - MiniGPT - INFO -
# 🎨 === EXEMPLOS DE GERAÇÃO DE TEXTO ===
# 2025-11-04 16:04:48,034 - MiniGPT - INFO - Gerando texto com prompt: 'artificial'
#
# ================================================================================
# 📝 EXEMPLO 1/8
# ================================================================================
# 🔤 Prompt: 'artificial'
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Texto Gerado:
# artificial. Modelos de linguagem como GPT, BERT e outros transformers estão revolucionando o processamento de linguagem natural. O mecanismo de atenção permite que estes modelos capturem dependências de longo a
# ================================================================================
# 2025-11-04 16:04:50,574 - MiniGPT - INFO - Gerando texto com prompt: 'Python  linguagem'
#
# ================================================================================
# 📝 EXEMPLO 2/8
# ================================================================================
# 🔤 Prompt: 'Python  linguagem'
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Texto Gerado:
# Python  linguagem natural combina linguística computacional com machine learning para permitir que computadores compreendam e gerem linguagem humana. Tarefas como análise de sentimento, tradução automática, sumarizaçã
# ================================================================================
# 2025-11-04 16:04:52,783 - MiniGPT - INFO - Gerando texto com prompt: 'tecnologia'
#
# ================================================================================
# 📝 EXEMPLO 3/8
# ================================================================================
# 🔤 Prompt: 'tecnologia'
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Texto Gerado:
# tecnologias de big data permitem processar volumes enormes de informação. Bancos de dados NoSQL como MongoDB e Cassandra oferecem flexibilidade para dados não estruturados.
#
# Aprendizado por reforço permite que
# ================================================================================
# 2025-11-04 16:04:53,892 - MiniGPT - INFO - Gerando texto com prompt: 'Machine learning'
#
# ================================================================================
# 📝 EXEMPLO 4/8
# ================================================================================
# 🔤 Prompt: 'Machine learning'
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Texto Gerado:
# Machine learning.
#
# O futuro da tecnologia está intrinsecamente ligado ao avanço da inteligência artificial. Modelos de linguagem como GPT, BERT e outros transformers estão revolucionando o processamento de linguagem
# ================================================================================
# 2025-11-04 16:04:54,929 - MiniGPT - INFO - Gerando texto com prompt: 'Deep learning'
#
# ================================================================================
# 📝 EXEMPLO 5/8
# ================================================================================
# 🔤 Prompt: 'Deep learning'
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Texto Gerado:
# Deep learning para permitir que computadores compreendam e gerem linguagem humana. Tarefas como análise de sentimento, tradução automática, sumarização de texto e geração de conteúdo são aplicações práticas desta
# ================================================================================
# 2025-11-04 16:04:55,933 - MiniGPT - INFO - Gerando texto com prompt: 'Transformers'
#
# ================================================================================
# 📝 EXEMPLO 6/8
# ================================================================================
# 🔤 Prompt: 'Transformers'
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Texto Gerado:
# Transformers são especializadas para diferentes tipos de dados e tarefas.
#
# A era dos dados massivos exige ferramentas e técnicas especializadas. Hadop, Sparência de modelos e impacto social da automação requerem
# ================================================================================
# 2025-11-04 16:04:56,941 - MiniGPT - INFO - Gerando texto com prompt: 'computação'
#
# ================================================================================
# 📝 EXEMPLO 7/8
# ================================================================================
# 🔤 Prompt: 'computação'
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Texto Gerado:
# computação quântica representa a próxima fronteira da computação. Qubits, superposição e emaranhamento quântico prometem resolver problemas computacionalmente intratáveis para computadores clássicos.
#
# A ética e
# ================================================================================
# 2025-11-04 16:04:57,945 - MiniGPT - INFO - Gerando texto com prompt: 'otimização'
#
# ================================================================================
# 📝 EXEMPLO 8/8
# ================================================================================
# 🔤 Prompt: 'otimização'
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Texto Gerado:
# otimização como gradiente descendente, Adam e RMSprop são essenciais para treinar modelos de machine learning. A retropropagação permite que redes neurais ajustem seus pesos de forma eficiente, enquanto técnica
# ================================================================================
# 2025-11-04 16:04:58,954 - MiniGPT - INFO -
# 📊 === ESTATÍSTICAS FINAIS ===
# 2025-11-04 16:04:58,954 - MiniGPT - INFO - ✅ Treinamento concluído com sucesso!
# 2025-11-04 16:04:58,955 - MiniGPT - INFO - 📈 Perda final de treino: 0.13573117554187775
# 2025-11-04 16:04:58,955 - MiniGPT - INFO - 📉 Perda final de validação: 3.0752675533294678
# 2025-11-04 16:04:58,956 - MiniGPT - INFO - 🔢 Parâmetros do modelo: 1.21M
# 2025-11-04 16:04:58,956 - MiniGPT - INFO - 📖 Tamanho do vocabulário: 66
# marise@sptech03373:~/Downloads/MiniGPTv01$
